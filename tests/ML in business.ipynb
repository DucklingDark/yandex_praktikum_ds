# %% [markdown]
# Оборот и себестоимость

# %%
revenue = 604000
cost = 34500
salary = 63201
lease = 32945
tax = 0.06
credit = 230550
total_revenue = 2.5
investments = 10
visitors = 22755
customers = 555

# %% [markdown]
# Валовая прибыль

# %%
profit = revenue - cost
profit
# Out:
# 569500

# %% [markdown]
# Валовая маржинальность

# %%
marginality = profit / revenue * 100
marginality
# Out:
# 94.28807947019867

# %% [markdown]
# Операционные расходы

# %%
operating_cost = salary + lease
operating_cost
# Out:
# 96146

# %% [markdown]
# Операционная прибыль

# %%
operating_profit = profit - operating_cost
operating_profit
# Out:
# 473354

# %% [markdown]
# Операционная маржинальность

# %%
operating_marginality = operating_profit / revenue * 100
operating_marginality
# Out:
# 78.36986754966887

# %% [markdown]
# Чистая прибыль

# %%
clean_revenue = operating_profit - (revenue*0.06) - credit
clean_revenue
# Out:
# 206564.0

# %% [markdown]
# ROI - возврат на инвестиции

# %%
roi = ((total_revenue - investments) / investments) * 100
roi
# Out:
# -75.0

# %% [markdown]
# Конверсия

# %%
conversion = customers / visitors * 100
conversion
# Out:
# 2.4390243902439024

# %% [markdown]
# Покупатели из конверсии и посетителей

# %%
conversion = 2.154
visitors = 21824
customers = visitors * (conversion / 100)
customers
# Out:
# 470.08896

# %% [markdown]
# Посетители из конверсии и покупателей

# %%
conversion = 1.821
customers = 712
visitors = customers / conversion * 100
visitors
# Out:
# 39099.39593629874
